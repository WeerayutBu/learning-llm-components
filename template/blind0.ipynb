# %% [markdown]
# # Blind attempt 0 — <mechanism name>
#
# No references. Raw PyTorch from memory. Copy the next version to `blind1.ipynb` for the next drill; promote the verified version to `main.py`.
