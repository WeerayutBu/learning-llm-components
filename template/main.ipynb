# %% [markdown]
# # <mechanism name>
#
# <one-line takeaway>
#
# *<intuition — the mental model>*
#
# > House style — delete this line. Prose is the shortest part: one line per section, every
# > sentence carries a fact, the code explains itself. Numbers are measured, never estimated.

# %% [markdown]
# ## 0. Setup
#
# <what the reader needs first: key, deps, network?>

# %%
import os

from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(usecwd=True))   # keys from the repo-root .env

# %% [markdown]
# ## 1. The gap
#
# <run the failure. a real wrong answer beats prose about why the mechanism exists.>

# %%
# demonstrate the failure

# %% [markdown]
# ## 2. <the mechanism>
#
# <one line. let the code explain itself.>

# %%
# the mechanism

# %% [markdown]
# ## 3. <it working>
#
# <one line.>

# %%
# the fix, run

# %% [markdown]
# ## Weaknesses
#
# | Weakness | What happens | Fix |
# |---|---|---|
# | **<short name>** | <what you observed — the wrong output, the number, the error> | <what to do instead, or "none — <what to expect>"> |
